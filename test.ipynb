# %%
from datetime import date


a = date.fromisoformat("2026-04-20")


b = date.fromisoformat("2026-04-21")

# %%
import seasons.seasons as ss

minutes_ = ss.calculate_minutes(a, b)
minutes_
# Out:
# 1440

# %%
c = ss.number_to_words(minutes_) 
c
# Out:
# 'one thousand, four hundred and forty'

# %%
words_ = "LoI xinh, gai" 
words_not_and = " ".join(word for word in words_.split(" ") if word.lower() != "and")

i = words_not_and.find(",")
words_one_comma = words_not_and[:i+1] + words_not_and[i+1:].replace(",", "")
words_one_comma
# Out:
# 'LoI xinh, gai'

# %%
i = 10
assert i < 1
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 i = 10
# ----> 2 assert i < 1
#
# AssertionError:
